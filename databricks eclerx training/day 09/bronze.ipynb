# %%
# %run "/Workspace/Users/piyush_chhajed@yahoo.com/databricks eclerx training/includes/setup"

# %% [markdown]
# ### Set up the parameters for the notebook

# %%
dbutils.widgets.text("schemaName", "default")
dbutils.widgets.text("tableName", "none")

# %%
Schema_var = dbutils.widgets.get("schemaName")
tbl_var = dbutils.widgets.get("tableName")

# %% [markdown]
# ### read the source raw file (CSV)

# %%
# %python
df=spark.read.csv(f"{raw_path}{tbl_var}.csv", header=True, inferSchema=True)

df1 = add_ingest_date(df)

df1.write.mode('overwrite').saveAsTable(f"{Schema_var}.{tbl_var}")
