-- %%
%sql
create table test_schema.demo (
  id int,
  name string
)

-- %%
describe extended test_schema.demo

-- %%
desc history test_schema.demo

-- %%
insert into test_schema.demo values (1, 'a');
insert into test_schema.demo values (2, 'b');
insert into test_schema.demo values (3, 'c');
insert into test_schema.demo values (4, 'd');
insert into test_schema.demo values (5, 'e');
insert into test_schema.demo values (6, 'f');
insert into test_schema.demo values (7, 'g');

-- %%
desc history test_schema.demo

-- %%
desc detail test_schema.demo

-- %%
delete from test_schema.demo where id > 4

-- %%
select * from test_schema.demo

-- %%
desc history test_schema.demo

-- %%
desc detail test_schema.demo

-- %%
optimize test_schema.demo
zorder by (id)

-- %%
desc detail test_schema.demo

-- %%
desc history test_schema.demo

-- %%
select * from test_schema.demo

-- %%
delete from test_schema.demo

-- %%
desc history test_schema.demo

-- %%
restore table test_schema.demo to version as of 9

-- %%
desc history test_schema.demo

-- %%
select * from test_schema.demo

-- %%
desc detail test_schema.demo

-- %%
vacuum test_schema.demo retain 0 hours

-- %%
%python
spark.conf.set(
    "spark.databricks.delta.retentionDurationCheck.enabled",
    "false"
)
