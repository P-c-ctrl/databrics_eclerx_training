-- %%
create or replace function fullname_europe (first_name string, lastname string)
returns string
 return concat(lastname, ',  ', first_name)

-- %%
select fullname_europe('John', 'George')

-- %%
%fs ls dbfs:/databricks-datasets/nyctaxi/tables/nyctaxi_yellow/

-- %%
select customerID,  fullname_europe(first_name, last_name) as fullname
 from samples.bakehouse.sales_customers

-- %%
select * from samples.bakehouse.sales_customers

-- %%
select * from samples.tpch.customer
