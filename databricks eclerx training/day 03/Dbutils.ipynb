# %%
## DBFS - Databricks File System

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
# %fs ls

# %%
# %fs ls dbfs:/databricks-datasets/flights/

# %%
dbutils.fs.mkdirs ("dbfs:/databricks-datasets/eclerx_input_files")
