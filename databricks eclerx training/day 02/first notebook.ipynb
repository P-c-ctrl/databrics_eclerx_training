# %%
print ("hello")

# %%
# %sql
create schema test_schema

# %%
# %sql
create table test_schema.test_table (id int, name string)

# %%
# %sql
insert into test_schema.test_table values (1, 'John'), (2, 'Jane')

# %%
# %sql
select * from test_schema.test_table
